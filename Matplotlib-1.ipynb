# %% [markdown]
# # Matplotlib

# %% [raw]
# Matplotlib is a library used to visualize the data in form of various types of graphs....
#
# It is used because visualization is more attractive to look and best way to represent and understand the nature of data

# %% [raw]
# PLot used in this library:
#
# Scatterplot
#
# Boxplot
#
# Distplot
#
# Lineplot
#
# Pairplot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.figure(figsize=(7,4))
plt.xlabel('X_data')
plt.ylabel('Y_data')
plt.title('Sample Data')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [raw]
# Subplot is used to create multiple plots together...Lets see it through a simple python code below

# %%
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(1,4,1)
plt.plot(x1,y1)

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(1,4,2)
plt.plot(x2,y2)

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(1,4,3)
plt.plot(x3,y3)

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(1,4,4)
plt.plot(x4,y4)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# It is a very simple representation data technique bwtween two values.

# %%
# Vertical graph
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
# Horizontal graph
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [raw]
# This type of plot is mainly focused for identifying the outliers in the data...

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.subplot(1,2,1)
plt.boxplot(box1)
plt.subplot(1,2,2)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9d9873a020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9d9873a560>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9d98739d80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9d9873aaa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9d9873ad40>],
#  'means': []}
